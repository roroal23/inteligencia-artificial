# %%
import requests
import pandas as pd

api_url = "https://datos.cdmx.gob.mx/api/3/action/datastore_search"
params = {
    "resource_id": "0869e0dd-6876-4446-a199-8f670a359c00",  # id de recurso CSV/tabla
    "limit": 500
}
r = requests.get(api_url, params=params, timeout=15)
r.raise_for_status()
data = r.json()
# depende del formato; examina r.json() y adapta la extracción
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\inteligencia-artificial\.venv\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File C:\inteligencia-artificial\.venv\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
